# %% [markdown]
# https://gist.github.com/karpathy/d4dee566867f8291f086

# %%
import numpy as np

# %%
data=open('republic_clean.txt', 'r').read()
data=data[10:765]
chars=list(set(data))
data_size, vocab_size=len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))

char_to_ix={ch:i for i,ch in enumerate(chars)}
ix_to_char={i:ch for i,ch in enumerate(chars)}
# Out:
# data has 755 characters, 39 unique.

# %%
#Hyperparameters:
hidden_size=100
seq_length=25
learning_rate=1e-1

#Model Parameters:
#input to hidden:
Wxh=np.random.randn(hidden_size, vocab_size)*0.01
#hidden to hidden:
Whh=np.random.randn(hidden_size, hidden_size)*0.01
#hidden to output
Why=np.random.randn(vocab_size, hidden_size)*0.01
#hidden bias:
bh=np.zeros((hidden_size,1))
#output bias:
by=np.zeros((vocab_size,1))

# %%
#inputs,targets are both list of integers.
#hprev is Hx1 array of initial hidden state
#returns the loss, gradients on model parameters, and last hidden state

def lossFun(inputs, targets, hprev):
    xs,hs,ys,ps= {},{},{},{}
    hs[-1]=np.copy(hprev)
    loss=0
    
    #forward pass:
    for t in range(len(inputs)):
        xs[t]=np.zeros((vocab_size,1))  #encode in 1-of-k representation
        xs[t][inputs[t]]=1
        hs[t]=np.tanh(np.dot(Wxh, xs[t])+np.dot(Whh, hs[t-1]+bh)) #hidden state
        ys[t]=np.dot(Why, hs[t])+by #unnormalized log probabilities for next chars
        ps[t]=np.exp(ys[t])/np.sum(np.exp(ys[t])) #probabilities for next chars
        loss+=-np.log(ps[t][targets[t],0]) #softmax (cross-entropy loss)
        
    #backward pass: compute gradients:
    dWxh,dWhh, dWhy=np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh, dby=np.zeros_like(bh), np.zeros_like(by)
    dhnext=np.zeros_like(hs[0])
    for t in reversed(range(len(inputs))):
        dy=np.copy(ps[t])
        dy[targets[t]]-=1 #backprop into y
        dWhy+=np.dot(dy, hs[t].T)
        dby+=dy
        dh=np.dot(Why.T, dy)+dhnext #backprop into h
        dhraw=(1-hs[t]*hs[t])*dh #backprop through tanh nonlinearity
        dbh+=dhraw
        dWxh+=np.dot(dhraw, xs[t].T)
        dWhh+=np.dot(dhraw, hs[t-1].T)
        dhnext=np.dot(Whh.T, dhraw)
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5, out=dparam) #clip to mitigate exploding gradients
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]


#sample a sequence of integers from the model 
#h is memory state, seed_ix is seed letter for first time step
def sample(h, seed_ix, n):
    x=np.zeros((vocab_size,1))
    x[seed_ix]=1
    ixes=[]
    for t in range(n):
        h=np.tanh(np.dot(Wxh,x)+np.dot(Whh,h)+bh)
        y=np.dot(Why,h)+by
        p=np.exp(y)/np.sum(np.exp(y))
        ix=np.random.choice(range(vocab_size), p=p.ravel())
        x=np.zeros((vocab_size,1))
        x[ix]=1
        ixes.append(ix)
    return ixes

# %%
n,p=0,0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby=np.zeros_like(bh), np.zeros_like(by)  #memory variables for adagrad
smooth_loss=-np.log(1.0/vocab_size)*seq_length #loss at iteration 0

# prepare inputs (we're sweeping from left to right in steps seq_length long)
while True:
    if p+seq_length+1>=len(data) or n==0:
        hprev=np.zeros((hidden_size,1)) #reset RNN memory
        p=0 #go from start of data
    inputs=[char_to_ix[ch] for ch in data[p:p+seq_length]]
    targets=[char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]
    
    #sample from the model now and then
    if n % 100 ==0:
        sample_ix=sample(hprev, inputs[0], 200)
        txt=''.join(ix_to_char[ix] for ix in sample_ix)
        print('----\n %s \n----' % (txt, ))
    
    #forward seq_length characters through the net and fetch gradient
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev=lossFun(inputs, targets, hprev)
    smooth_loss=smooth_loss*0.999+loss*0.001
    if n%100 ==0:
        print('iter %d, loss: %f' % (n, smooth_loss))
    
    #perform parameter update with Adagrad
    for param, dparam, mem in zip([Wxh,Whh,Why,bh,by], [dWxh,dWhh,dWhy,dbh,dby], [mWxh,mWhh,mWhy,mbh,mby]):
        mem+=dparam*dparam
        param+=-learning_rate*dparam/np.sqrt(mem+1e-8) #adagrad update
        
    p+=seq_length #move data pointer
    n+=1 #iteration counter
# Out:
# ----
#  qW:IW)tW)rqW.wq;)AC,wncahipCPAu.,WBa)v:qAvhwew.f hh.uCpfm(lw,q(mh,bblWe(AsvIygtrsgr( tkbBhgPp:Tak,q.TkIqbI PaqIkcpiy:(msbB,
# bvpC;slb:fT,qP (sdm(vdBnoIa;eady;Towy)qkvrwmItG)pATB)PB:dyfqpgGhffl(, fB(.wb
# ----
# iter 0, loss: 91.589047
# ----
#  t a olCcar yoc,e onns ocwsb .to iwstrwatdenna cb we itn ew t wtnawre fwi ot woa
# n een t w nwbd bin  ra;ld no fh ltwmt we hfat) wodanocv ms,eeach lw obff viapadtltwaI,waiaitsoe t,l klt;of wvawa:ne n rw
# ----
# iter 100, loss: 91.670630
# ----
#  a, ay ea;woi eatc tsaca, r fcpi atitpwso,e et  Ieaoc eecsieB.aanaanure en,tc  nlcmhbtftniectar atiio te aphntiu  ott nodnnpiio
# t.aedottrna.ibcc elaahmbhvs at tt tatnttlccyttdn aima es tanunhwat etaa
# a
# ----
# iter 200, loss: 90.402953
# ----
#  ercdyldnihan urof;
# soio fdofewywbuio eogdthsoufrhdit, ab tha oTP,or
# wii ato e asotfastheisadw
# nptt hsfitidto s:ruaatoihtIraiie isato(orlinomasdetne
# sBponthrtofu,avn: sdtinbtnnrntsrisr,ot  oar ldedvomy
# ----
# iter 300, loss: 88.837605
# ----
#
# (roeeue anabhe ig a at u otiu or afcasnesthdl T
# hati;  d  oly eis ot aasvace wis , wag h; nduanas id fb
# caute dfdist aksthe wothr
# wI  nlhe : rdan t,t   t haralh ghiahata ta I ,reeisul ; th tean;caTi
# ----
# iter 400, loss: 87.022544
# ----
#  ohitrpiumheatabosrnadanrGrrne; asran it t,ncanuThadtasataPa
# d oralohoiptamatiyiithtteatanttdar Ihiic oniIftir sb thpiuver;tf aslemotatnaoedknniahooneie:angalAth itsoh eawrT
# nr.irpon ted Alitatamaedef
# ----
# iter 500, loss: 84.947538
# ----
#   war .esats hya
# rharasf auphl
#
# das s thrnPdafd P, os arehchheroovasdywCiarohe.s oan aCodtarogh gmoatoacoan Geian; Paedohof.iua, ar fe Grauhoha as Gs id w uin an
# bngon tem
# uy onnurhhat  Go efo anamTho
# ----
# iter 600, loss: 82.708387
# ----
#  hcrhangitherslooce Ie; t; ,elanthicarhastau.s as tos auseteeewe tthay waecad taswiman a Gthugeftha hat whraralancofoe vas iaas taratonse
# rh ekPth  pee waered te  TId wgha ,it. tha aee nese mauslofachi
# ----
# iter 700, loss: 80.343403
# ----
#  ansprpivhie tc writasuitos ourte; ann hiofechan yedGm Gulucitheanwaaoed wld emoleI anitiwe iyhtetchedkahate tesotiIe Insintted y goI star uhtey uo
# iebirann wy wayirian tisa Thoter
# treisd in thae oayan
# ----
# iter 800, loss: 77.867428
# ----
#   weowencen aslor; anhoder mo thatowes Pn
# we
# aha.o te faered on sod Cof I  Iopal uhemooosqtcauWoalmae;in: saf, wurar he
# id Ia Giaus yanan Piause taarPato ofithoek,c: vaGak iaet hin Pohf yhaaopas ofe
# wi
# ----
# iter 900, loss: 75.360802
# ----
#
# Is Pesathed thhad woe ba
# of the sere wtinsthipdego
# phtethechetey aGe In; ed Ahasiofd si.asureu
# waitithis urh t Ierighe oletacitoulae ah fted ths sharel, we tawnn no, altss hasss th.n whiwus o way aon
# ----
# iter 1000, loss: 72.862910
# ----
#  on thaw,
# ptain wh wastis inaedoclobetid annerortaften waqutochaly;oione ra:
# ole biipiesoitin thiwy thutnd aPirb.ayelrof wh thtaroeltoanth,
# indun rattiahaontifttante td toteratofil
# tcuuciton of
# rthan h
# ----
# iter 1100, loss: 70.301405
# ----
#   wonwed tsaloo oferwhltansirihhofs trass te moala
# I widt h aneos .(;an,ivaec on wou ondlraye u too soin th uthas foulho an sois th Iclaraional ouibe Ioain ahegiterherauthiromameroI torwheeed to; onos
# ----
# iter 1200, loss: 67.749181
# ----
#  harsetheuf. s ha of af sheoheof ed of sha(ofewarsis o(awor ofabhacawos annerGrarched Ihe that touooargich wis andyare,
# hoin Iat otisganhrad isathachatace Ie Ie to
# loaanr.an Whed sor ghusont manced bav
# ----
# iter 1300, loss: 65.165102
# ----
#  reonntostintiand paan. dGh we; andioft
# tand goatifanswirithimethauriyurprthr Piawin pishartcan tis
# Pialemaand maangh,
# aftandison thtaripis aut maintok eqnepaf. ghae:uind pis, eitc
# PisbpviecirherPitiIe
# ----
# iter 1400, loss: 62.608804
# ----
#   whul mewol vinto dhhthd hey of toyenThat to
# ratod rula
# sangof dod ohan yor andI surnecstibopourhrandtunyrsiootis thaanddhitorab.unlfiouthcmhak
# de smaan o
# t,k toithe thaton. yatha
# nghad to sofd iaur t
# ----
# iter 1500, loss: 62.539964
# ----
#  hed iran w. anvanf wurcit wosvacan duithiou erevante yot sevaltay kano valingof us thitWe, wirwanw rf theaf waro; nged w)us.afd wak ofs weapebeoGus sirheshe beaalanchausis Ptaneyied: byefuprracn wanle
# ----
# iter 1600, loss: 61.747584
# ----
#  rae be fatans wort
# nhe Pt ss nttomernoriyansathe hin ch wathe n; Whet thaechtapsanur. wheabq(arGhoarsiwhe petus yning an, thansrard oins
# wtayf waate wert atant. (Bal., heltyep Whinon be s dls,rs yer
# ----
# iter 1700, loss: 60.557347
# ----
#   went th.d Phe thatotinof hra
# Pomdancaenc.f ton so
# rhhthay hulecod wanf bit)atdd mooist vow tiwaed ofd bhand won); sow
# indheinryapik
# (BewnrrPurifren of ins byou sd won wole; an rneirhe
# wecleau y
#  yo s
# ----
# iter 1800, loss: 59.086745
# ----
#  h ao derdtedd the f va on yh whe we ti(B bus thermtnoobes Cedus olemhaoof toney alue,
# rausith wertiancy
# df Ie yes wsr hiwaemh (eenBeyhey ofle hotecin
# ve thewithapcs As ruiAn (heigo
# kstamwaTbuu bmawhe,
# ----
# iter 1900, loss: 57.521636
# ----
#  nomvandiyrignlgdrwatn uray secand f
# frwast un the fraPistoyersrt an anv
#
# bayerocayes tom afrarper hrwaycewees, nandrand Gcof chekemayn fathins praad pstasto tand f
# ithhac don vh Gf  of ind Pisann thiw
# ----
# iter 2000, loss: 56.243130
# ----
#   wfrterhed by waited toand
# that do afosl I Thel.ur thatoin aokencvad us tolemaso) sal. toetdab
# andittit in, isob ay os in ocarto t aBeof theeddusd bpay ocoft) on oht wocohimey th wad Pald iat viandito
# ----
# iter 2100, loss: 55.007167
# ----
#  o)taremat wand,, conyarausrs yauomvant, Ius andeoole shance, Io mos antthe Thet ta waranderaeasis thed we waruf pn icrals Whec Iinatarthew, vouts whang Whec: ofe ofis an as that wingerus I n carchatk
#
# ----
# iter 2200, loss: 53.219791
# ----
#  rti(ato thindsParssannrsriby;halef on werpaynrsrt n memhasniry chten sarvanlerraGc the cl.anvinot sawastattimh taecendindintintouri thang ancopraychan: theuss mhiyhtantt I andinvion ghe, I thec wandit
# ----
# iter 2300, loss: 51.354096
# ----
#   whuugauusert ay: too Thes on ayeracint the frr oque I garauusarsianserus ioolerus
# Pon of and ; antathen the
# way htatolon an
# rinld alcprer fubofemay the nouad to calee sawcoat of I waclerdiof thingeac
# ----
# iter 2400, loss: 49.372966
# ----
#  he feragas on ouluanaann Gacilacthat: vayas angande andangoufers us eday watly rhe flay,.ad annervandinerocan of to of to tfat I  alayf at animanyedisw to the Aeohesain: of andy the sarch touwantrat w
# ----
# iter 2500, loss: 47.681964
# ----
#  rawaus antintayhin thacle,
# whecind, PhithalisrertaroesaanteArayerdalatd G uf we co theide,hanny; anithalchequannon blof Ght nity; andinalitanocancquad annedce,
# beGlwoligo; anneraannd Ghithoof andigot
# ----
# iter 2600, loss: 45.665742
# ----
#   wedt
# nus wausin; thacc.asey; ontervandt; wato
# ols and tocemaon aisarco of
# saraw ianfersathe t uone fol malem on, the Thot of bon misarastad ouit a
# dirar pre,
# on anas an tonlaunca f os anprandtalleray
# ----
# iter 2700, loss: 43.585473
# ----
#  heofolertatharl: oninont meone I
# proherday thatofte
# Paramonk
# tghe bu vas oolethe I mangor mast thoal s watcha  on: Puangatomastervanderran thang of w on moful yos whas das aureeyintepral, Thllebratce
# ----
# iter 2800, loss: 41.589660
# ----
#  ri
# han otarthan
# ufuastartannthihightand towaquas antannequis ofah wast ; ayors antt; anty; andayuascertannttaif war(
# Ple that Past for pat fe in nhoulyarhaut alapraruanded to aqular Thelstanlmaoflebih
# ----
# iter 2900, loss: 39.598773
# ----
#   won
# qoclus ant of wa ses sartamas on maind als thewarchacitan ohe Thiuld
# raaly wally; at of sarchac tanti; andto the of fulatthat
# rouleras Phtarlen to
# ray the
# marom bul. Powemordhe yoh to thabutalman
# ----
# iter 3000, loss: 37.912111
# ----
#  hebman wan ta
# n,pran ur Thes on ad to b. I was ifhe I prancod to whraust at to
# Pole, an thouce indy; ole, anciand ; ancha shon we the lan The
# psaPceonchece op anraca I ; oolomaesePntaonerned the The G
# ----
# iter 3100, loss: 36.054165
# ----
#  rauGy to
# res:astarnesceraantervand, achacd antarGe ce wan y; of ar anne yasGed ifteraeruantertanteraantequad wer(Becone tator ochatche tayne ce Popecdacley;ang.aqdaruaut praycrspuctancerae aofs ppanto
# ----
# iter 3200, loss: 34.166882
# ----
#   wendsa s(B
# f Iimtht
# chis thh non mironn we t mayesemay to tequaluy an to
# tof hhas. toule.istanay tour cayceus astervan phraed I aquausemsanfinar
# Phold an tht anf fal uo
# rantto and Are
# valumartewald f
# ----
# iter 3300, loss: 32.376933
# ----
#  he fhae, naedithatoat ton ArabecPato; annatGrtansrafus on andatot The I mang.y; ous htausuce biant wo derarcaucory; andranciae: th ok Pura,
# i
# rlemestannequl uarvast son un to
# Gequacteraand areabistafu
# ----
# iter 3400, loss: 30.738649
# ----
#  rhePchay on mast roligh was uquausiraed thing.y wartarnervaste; anned toew Gnton to on tat rigd of the f, the Thaupth the Than or and gcertaltarner auuliranof mo
# prauco to afuad ares inraanteraedisarl
# ----
# iter 3500, loss: 29.106438
# ----
#   w tf of we,Whangon wa cervancerayctoocanvanned toul I wal me onsatiI The hervancequalu
# Thald, and te the fiautos ancerofrabstanchral fomeint
# thees an the hequaltaftaut mors thand tauchuaus arew of to
# ----
# iter 3600, loss: 27.527387
# ----
#  he finomy; Po  waiten on the
# is (fandet ancmawhis waraed on folur I to of andrandh to braoupe, to nhitomasbeqtaley: Wten ma ne
# ton thabArandi; andrecinganalayestannerat
# to th on tht oule taquawas wof
# ----
# iter 3700, loss: 25.976101
# ----
#  rofuasus wolls on was urae si,orPiou un aquant Than Apacs (Bondistandingon, bhan w s
# inay walus an wa th Ge to thtantonce anay naishelehedisarchaece se Ius I warup viy Pole, ans.afulithhec wancapand t
# ----
# iter 3800, loss: 24.543573
# ----
#   welerafcalyy;:Gs:yewaygnlganaycpy
# Pole
# bich woramay waiby; Ius siant fal waiceraaw to an ad to warcaus in,tof Whoc makur Pou shan,
# brhe
# prauchacle Thlaechaul.); I
# waanfwasky Pulw. GlC;(BGn:GgB:(Bk(B,
# ----
# iter 3900, loss: 23.115498
# ----
#  he, wally th waecervancaran tifus the t: Phingof tis fhi
# cacitaCyanvasiy; oulorvastaquanc, wou d aour y ald praus me sqeaturaay the Pfoulus wotasteruant f acn belmand tounwatou wathe Thee tha Thiof ba
# ----
# iter 4000, loss: 21.867038
# ----
#  rhaub tally; ofe, andivat
# pon wad anbe
# rald folurithanceraconangatian biangaiarvanlathtand to barast of of ufewtallypralmanay,vWBe, I
# rphails anoequalu, holemart th war aunewachtantiful. (; on araeeci
# ----
# iter 4100, loss: 20.673506
# ----
#   wanlpaybic: as anPanned in bhPishannemay,
# Wquautoros ans toce I
# Glauchay Iomagdiand arewall. Thelmandy the se van mar pnhiche
# d thed wantiI ak Whalcaacun, the, wancay fon binomastervant for uu tanne
# ----
# iter 4200, loss: 19.437408
# ----
#  he of une,
# the goleminny
# Poll, an, annrw the Piancy whe fervann
# paule; ron tor warterally); Thousrerhe nftalmma(ymBWh: ywat
# boun maqul. th adssarus and wadce Than that Io Gchalorof wer wance beche The
# ----
# iter 4300, loss: 18.674561
# ----
#  rc. ayes yo
# oervants; Thiy th Gcarasbe the got ofus.); an the finomanne
# Piatchall.y; ous chas erayerartas Wheuf an afntomasterold thecaraitannancesol. Phance ; ane ope becellman:e; (Bendes abduancequa
# ----
# iter 4400, loss: 17.624880
# ----
#   wan,,
# ian wan tamay toolaraad es anned to nPiaul, wht Whandes wan equally (PAwandaitanustarpey was eraaut mor ho
# ifereerants; and tonthendof aon ton sePol. Whtand f auled in whiouw maycay wan s wallu
# ----
# iter 4500, loss: 16.583520
# ----
#  hin wte od to whiour wat I d of that mom of ande
# Polus o
# d to nhate than ffs antanneruas Arat andithat I marof praupom on of and vie
# bian
# praus of uf of we cheansatcfranay
# rf un wae re the fiandy yo
# G
# ----
# iter 4600, loss: 15.591322
# ----
#  at: ancte theof omoa ne
# pr; ant on oprenifurauf
# Po
# us ay was is the gor hom thithi
# ,
# toul want sol. to ast
# tancervaiterafda disprt
# Pole, of to
# tor of aquantthate that wasus aod sion we
# binat
# als Phe
# ----
# iter 4700, loss: 15.260366
# ----
#   whiedisayWhalleyganchand, andithe tiraPob anne
# ce I mhan anay, the Thole, and behis thance ce that onler chan I mon wee inay Iomehtan toaus was eraaulep all,
# anl. Thef and of pay wiaus of tod sertoma
# ----
# iter 4800, loss: 15.013803
# ----
#  he The cht and tiensedisaygha
# de tarfinot Thracaprautianastasoe by we harne ce the so the direm Araa
# spraunemaychanceereurestantanner find th was anne, the Pious one
# thald and tol fioae f aun atautero
# ----
# iter 4900, loss: 14.197172
# ----
#  rtBand tathawak Whe Thee
# braniytfth Githancedithe t
# raeus andsalhe ole, we tat of apcaynran bea Pfd autifol PolemarcaPald, withan that Io
# watiecaald sol,
# rhin
# Pole, ay wolemarcatchus thea ,
# tatchaclea
# ----
# iter 5000, loss: 13.353543
# ----
#   whiCranricany ther wo dirain: (Bendistarchaccerach and solemartannew to Whechiof nhithta tanvancecan mae f al, hh citartayced to whis whi of and warihannes ion tof masGe iWhelimantaut rof Pos nhalf a
# ----
# iter 5100, loss: 12.563840
# ----
#  he o
#  ulemarchur phalle,
# rolephalleb Ge: ant firecit
# nolervally wa t tarthe
# prarcarchecarud oul
# biauleraslew we hor When waecaunrs whito warcata nervalus wo tauned to wore to wannervantd and the The h
# ----
# iter 5200, loss: 12.088960
# ----
#  rcaecheadiannt
# the van
# pral
# prat und Whe gook
# rouwaihanhatcaus If Gaenewathin wae s ache I
#  uf beaucemang. oo ofestandarneiI behith; and alstondstarche
# ,
# the waright an andsarce andrandtand saler aule
# ----
# iter 5300, loss: 11.386774
# ----
#   webe
# (Bend ny hostonner
# inne
# Pilu
# Arof note blarcar chae se toandatemwonishanner of Ar to ch and mand to t no
# ron andrecsarcealprantinae I warup fulauchat uo, of and of sor sians waece and oold aou c
# ----
# iter 5400, loss: 10.698228
# ----
#  his,
# Patamarchon aratsay walus and tled wa ty ho tof as tocasnrs andwarus and biva ntion or annerat
# Palo, an waecs the spanchanceraece Piancedistorpras a
# t at wat eo: Poles an that wand warup ton wewa
# ----
# iter 5500, loss: 10.055559
# ----
#  rc.uadceanoatch and wan us wolome (Bendivant: and alestanterall.y; (B,
# rI Piewen: ant fod ro tarner anis. Poulom rhe hemayghe
# praccarchisowastaruathithen the tionstarcaPas y tho chtaut prayheuntaan, t
# ----
# iter 5600, loss: 9.472596
# ----
#   we fraadis a
# Arioh cloaPiruauces anay to
# tar
# ak the chancervanteraele chas on d, thecarainerGaune Pos an fan warus praypran arcar d
# ooedrat Pol challey:waecs ocs (Bendistarchae son Pioted oolwand tar
# ----
# iter 5700, loss: 8.905221
# ----
#  hin wo
# run and of warce are th Gler chancarauhan, Phicarasde yer.y ay wi
# huran a
# Araus prayes wof of andithancer ool, woll, wee serbehanctanter whaecs; then the caras anta war aine
# Pilu
# ,
# of and
# bathe
# ----
# iter 5800, loss: 8.389012
# ----
#  rthaul. The perals Whecfuautinon ro
# rof aun of phan andtard hod soay the sarasus woe chalus praye The sbecayer hom and tartinast wait f.r
# prantervar oolaby: (e, chaucee tomarvancmalus ant olof anne. t
# ----
# iter 5900, loss: 7.891843
# ----
#   weis, I Gl. bBe
# sanchandinay to
# rus and tivar(fyand The con ad fon of ohas arner to n the servian
# rant fol I mor hom of ofing they wa t torthe
# iihalurachan figof s on the chtanty; rae prathe staat th
# ----
# iter 6000, loss: 7.427564
# ----
#  he Thes th ants; and olepranterol. Ahancitabiruvar margha
# reepalus wo
# lufrancequants; and of prantomannathi(g.andin. Pilsrandeertitho catch anny wolep alu b. af d toe the d olede t: and of fer wasto;
# ----
# iter 6100, loss: 7.549097
# ----
#  rthtantanaycit
# the cpaand baeleurnadce f distablhalus whe sprafte claucd an anne
# Pi. f touls wanceqtalt, the
# birange I mor hir ante
# sarce te tervanteraant sol,
# rrulayWheck an ed to nor Pinon, witur fo
# ----
# iter 6200, loss: 7.685323
# ----
#   we fracdirtheref of nowesianne I roe the spechacleyarche diancr; an anntartarche gor hurnanceechald ioulerat
# ra Po thecannerithe The praccs and alstoalutrnton hollmanne, the merecifhak
# brathe The brt
# ----
# iter 6300, loss: 7.368407
# ----
#  hey wollmarchtauss
# rhe chat us wautewall,)hthe ss ofinha
# ciannt
# on was s whice Gast the syrat
# the banthat I manntathersphallm(;I The servanteraan sarcaus mo
# reraant I auree toclmars wht of way wolls a
# ----
# iter 6400, loss: 6.960862
# ----
#  rchus woul, and tol miyew roa Po
#  an marchaule(Bendole the Thracisrantehes waiteraanceway
# tad fnay the canafuf. tat atht and aniaus waiteraant tirahre tu y,
# ifus an of to
# run annr and taPnrraney woers
# ----
# iter 6500, loss: 6.569589
# ----
#   weiss I; olwanned to n of the nnat
# toropran mawvestantathe
# prhat Pas servan prae
# phat uf was arnanteraants; and of way I marThici,.wand tols Iowast ;oe hoatanne I way hof to of told of waecaunghtande
# ----
# iter 6600, loss: 6.190064
# ----
#  he The brtanchoar uclannho
# d taecs andranstank
# ber that ch the aerthancerayd of ncithe meriethal, this wae s th Go Polus anre of nd ancant I
# d an y;itold of wasus oc to
# rertants rhe carchus the specta
# ----
# iter 6700, loss: 5.835485
# ----
#  rcaPt the ss afte yemaant Iondathingwast nor hia chalceant tor I shequa ty the beran to thecf aut way,
# the derocessannighet told iou of thacleay ront
# Pis Phe Thrac an a
# cerasteraances wo s I aGsAr(Ben
# ----
# iter 6800, loss: 5.501588
# ----
#   weis,,ofGervas(yby:G(:)); (Bd(Bd,:.(BmTTAl, whin, anted
# is Whel, this, the Pisamchaak
# beal, thta thecervantsarcauc I marfun I mon te Po taray to
# run ands anditimy;iande nof and tirthan ohel. (B:n Go
# ----
# iter 6900, loss: 5.187931
# ----
#  he diremes aciuantarcaty the sprankeraant and the ont offer uf uurithtor sovay to
# run ands an, ant of prayers of ance bihte unres would antingous wath was ast thanclarchua manny the shelaPus afte yas
# ----
# iter 7000, loss: 4.898083
# ----
#  rd had and aider pon of the spechaus wath waecsecstandithe feramcha
# Arion caele solufnranchacus ay
# ko tartannew ole, we tarne I warulkprafus of to
# run and ande ald arsere; and of chanced the The con a
# ----
# iter 7100, loss: 4.626756
# ----
#   weis, fBecd ally Poles rhe cpaact ton my; (Be
# dels I; t
# and tal, of wanced to ncrechuanc ta Pn of wast ror anr of ou oul tarus s anis whe sinnhand the fewachu sor chancequaluprrWhed hour prayes oour
# ----
# iter 7200, loss: 4.371731
# ----
#  he Thee, prayersaw pom Wheuf catcheak
# Wh; d iauchtauls of the sou
# s (Benditthus s ao
# rechancerne
# rin ands the ss (hth waruayof ansiththaw mof Po
# lan fon beaucecaal, The serat
# e thaw that Iomangorchis
# ----
# iter 7300, loss: 4.135510
# ----
#  rcoua f toancernist);irannon of uce taruaulew aold wally;wallyganlsvand thu chta tar ancs yolemarcaas was y the son the servart tietheciur of Ad fon of mhancecay hou cano to; anntoay
# rhu chtastd; on d
# ----
# iter 7400, loss: 3.915316
# ----
#   weis, yohls prraly, ole The servathathet the der hom ants and ale oolArvancarsarchacle The son of ArelannroP tomer hou of the Piouleree the sonastedol. than, the whatcrosthe fha buf cleannttand us an
# ----
# iter 7500, loss: 3.710332
# ----
#  hec the sp afus af the stoht ofind tout of was aoner and tat Iim. Thes thew ifuaan toather ante yeway ioh chtas ante tan fon than iran
# rou standes won an to warcatchal to
#
# smanntandirnl,); I wer and a
# ----
# iter 7600, loss: 3.519259
# ----
#  rchua to
# rinry to buhall, hrous ches on ancttanle beasce; an the Theocervantsarcarch an solomortay,
# taechel I an saecheld rof I waripurnervaldus antedistantinotyron wo
#  of (Bey oh wat auhe wasus of ta
# ----
# iter 7700, loss: 3.340018
# ----
#   weis, ankd of af ak noanca(k,
# r(Be, eGe
# Pily wlew, hul bun maruw ros cout pof wasteroad that maen, ay war fhaluw of ofew to nsatchictander Whes whe fan ton suarcaran ohis walus ohe ssr(Ben of the ss
# ----
# iter 7800, loss: 3.173254
# ----
#  hingof the sarcarcatof as and to fhas fhat ho tunvanner (Bes tof d an warus an clatcaulitantannescertand
#  andus ton d an, to aity; ole Ine
# praa
#  the spton fraok be t
# Pilus ancaychus nony was a nyeca b
# ----
# iter 7900, loss: 3.020831
# ----
#  rchua mance pracistanneray,irerast ;om a
# prant for hir., hhe ferautiruanny the s wan y and on the Phou der ohand tarchand anertand tiithedis, Wf and alew aut ptatho
# rstond sortoango(Bef; tt and olesta
# ----
# iter 8000, loss: 2.878862
# ----
#   we t andat
# Pist aorthan that the sarcan
# d to nd taecpraut roathe
# sinay to taureerant
# hthithawle the The hud to s ous (Ben tou son of that thet the son abionewaantan
# rtay to
# run ofistatoan I tiancedat
# ----
# iter 8100, loss: 2.745538
# ----
#  heuw inwe Phaen,. ThilanprvGl.)pr(Belithanpabrhe
# tathacerstan, the sbshe lenonnonclemersa
# Phei,
# thecaeus Phe nst cne the ce anse, ofelesanclen of ward onnren way y,
# rle tanhan on ton sannew the chause
# ----
# iter 8200, loss: 7.512774
# ----
#  nn
# rmata; wot mtanf ;ryanvan the fer I aphancan
# prantou the tervanhayedgkGWhi(BPThi(:ncobron of Thlaufleptar
# prachaly,
# rhePonn wastayervhedlyWhci tf th
# bingancelevacbeef wancanfe tarGranbecandurem; (B
# ----
# iter 8300, loss: 12.259688
# ----
#   weche sordhel.unhr(prauc: to; anCeqerslyn:dqpnawes
# ArheAwerautouf ton mThelibT:); TWlecann thals Pflay,Be
# dr(mI(Be fholl.);); (Bwralerwatte th ohele, Pi
# Th(Ce, onof Thrands voled of Tnre, of wannr; w
# ----
# iter 8400, loss: 15.369493
# ----
#  hatemanhe
# iou skanhi(BeAhoc of: ihaiceva sondemy:.);eAtis
# mangg;he
# claune bBe, ofund hole, of: fus warch anApeche of Thlautha
# k fon of phr I Thaule); hiand th themhomcaun (e an werant: Polesr Ion Af;
# ----
# iter 8500, loss: 17.518500
# ----
#  ncht The I tin
# myahtle, of: fhaifey uf wanduvalibr; ant thithewhelipracled
# I (e ante
# bihersr(BPus f waet thalt hol
# cquled felephally,g(BenT: (Becit); ancas sfaGle, Gfliy
# rrauneheqhr(BvGlauhelinkr(Ben
# ----
# iter 8600, loss: 18.825882
# ----
#   wantithaGle, I
#
# t); anso; aney we van: Thvullf,swandsraus, tour whe turosthe, thalit); an
# Arecace tuntayerervald af hul. The thaGtat I Go wirhanceral: Ghigos ancour: anhe terhathe(BePhe myWhi(Tn(Bech
# ----
# iter 8700, loss: 19.630145
# ----
#  han yer ff t. of no nracaunrof I acas ancele, htliy as andesansanre thiwtinBenhibBen hul.); (I Whe Thracirer hthulighhe the Iy wat the qecaunrondertaPhew dole, no
# dur ancsance chaPig,
# erlatoans the ak
# ----
# iter 8800, loss: 20.192329
# ----
#  nce fBeAthe,
# rhalise
# rsTe thimervaest The(mb(BB(k
# AAdim.)hi(ayk
# tas ofhe wannstre);rhe themhufre
# pr; dold oflancrvanton
# tathe Thracequr: the(
# pr: woweqme): Wkval,,
# r(Be
# Ar(Benhiby;i(my(Thik
# bir(kkprGl
# ----
# iter 8900, loss: 20.460465
# ----
#   wecat that tontechiof Thaecerde, iofk
# r: Phid
# rfnts; IpeAwervheqTn:);qTn: fn: con ofbCes ufk
# nW: yTe werauthiygar
# kdhof.s alinI ThelmyPCekknAsestsnwey: Whe al); IThechecigprecaynrande aprannwenThtaly
# ----
# iter 9000, loss: 20.509018
# ----
#  he to whe
# cranclay, am. (B); w; yq:PimTT: nigchalus phay of t
#  antr; Whuf than yerae anteciancr Whe Terawithan,swa(Befhe Thraciont
# my: GBe Pirtivigche sof her fhof wesherhelinha(e bBes:.);e(
# epme(kg(B
# ----
# iter 9100, loss: 20.425631
# ----
#  nchockachay,sincraule
# bBheleyWhGlibB:Gkk
# T:emye
# Ceclal. (Becht e
# behi(gPArifunn
# Pi:ecaucron thaustianceceuprservacast fta
# pracbon k
# bhhiqknn:W
# ChkCdqhhiTI we(Ben:echebion hbihay:r)I The gn w
# rhe
# ishe
# ----
# iter 9200, loss: 20.253028
# ----
#   wechingrranclly I wainf);eA:t;(e); I wes th; anne
# praan: ffhamirprally;eA
# minerThiWhy)
# b:k (Befirbay)by;waste , nBe
# Aer. doe
# of tolw
# bihedsr(myawe
# can: ton ianse); (Bef hemer:rvi. Thally;:); b; ale,
# ----
# iter 9300, loss: 19.998344
# ----
#  hat un I ann by; n,r I of ant Theaciral. nhew. oferasranthe Ter tol.); (Bec: wofd minh
# bance Pirus asrecinte
# Ar(:;Posd wawey thithrhracir
# s of: PfePisvad tof I hicl. Thtamy(gh
# me): fnes) Whecelaynrbpr
# ----
# iter 9400, loss: 19.608439
# ----
#  nch
# biufrtayervalpe, an en inouf the of thigho
# practo ansrviof ant tham. I (Bechid,
# thecaycine du; phar, ipe
#
# pralll,ndoflonAstathraciBerde as at ine, frely the ofn
# rf; When hfm. Ih(
# Pr: nd thiyprnTm
# ----
# iter 9500, loss: 19.163700
# ----
#   wecaen the matbstanwb(Bek
# ynttatirauned atithr(Bv(Th ttoay, he werheld,We); I we te,
# hiBenT:; gon thaenshe
# r,; whacle, ufll,; (Ben
# ofk. Thl. Whele,gat,
# ransranind); fd tfon wna
# ty alce Thr(ByThem. Th
# ----
# iter 9600, loss: 18.592693
# ----
#  het nf: chi PheleyThhluf(Bvn: I tus nonnons. che
#  I we the therlann: fne,
# AG: PfllCyP(leqTh TesalWe cith brauns wito
#  that an of my; fh o
# praccle, I ause bianced an: fBen I weramtann
# hy hullmanvion of
# ----
# iter 9700, loss: 18.186735
# ----
#  uchol. Whecof svanhyGyggwbGhel. fulacy,
# of withay,swa(B:Pa. ffyWof,
# baus weramy hele, Inhe Thracye
# bitWhiayneqpusts; the tofk
# b: nhigofertarvralerefhi(Bgn(Bakk); I wesathinannebaed: Theg. non hol. hhe
# ----
# iter 9800, loss: 17.550280
# ----
#   we tod we handd a(BePianThew
# thecolyghi
# y,ArvhllusgB:n: Wf Wk.In. I watthauserbiGy: fon offrto Grebihuf dlaechtalofk;ye
# bBh. lnqid: bfquf tfervant
# rn
# hallufor
# lyaunAs,perh
# y wn wesatht andrand en hul
# ----
# iter 9900, loss: 16.964582
# ----
#  he Thracta non offnd alifechibras echecacne ndelauflancetarvant
# thhan welefThramyanchey sfance fhate the Thraler the Tertighiy
# was of then ye therek fht offsto
# gannewhemyWhrGkkbThek thauftee thlafd o
#
# ----
# iter 10000, loss: 16.370025
# ----
#  uce WhecemyehiBerhat
# ccercon fdas afnaw thecatashes anne(heqed: akyr(mauTsmande,cerchulobyawclabkelibycel. Whechindesanf: yollepron werand eurecaucht
#
# prhly wa h westaithemayprvals wall, anlif
# prvadPi
# ----
# iter 10100, loss: 15.809933
# ----
#   wectinowest(Bechinof Thr(BdkecBem andeb(BWk; WhPittof of Ares wa perecivandrvalkenref
# rurhancAralleyeecaunrrastoflmaankebih);.);. Theuiy, aGley of thinfror,leThr(Bene); fThifmyThraunf the annewarus s
# ----
# iter 10200, loss: 15.184155
# ----
#  he thracus on fon ofdArsaufntaans Pflay an: prar
# ston ony
# uTheaBere the ion I haliprne
# tivauneepref yes annfeyiner(edesranflef I
#
# cclaykghe fqyhe ffe
# Arvant was fchemey anhiyhival,
# che shal. uf.akprn:
# ----
# iter 10300, loss: 14.621978
# ----
#  ay:eciondes I the Pin fThaulyThe fd westathe sof thhes rfhhay,
# bichinghus fd allyTel. I walCyThhakwnesprvird on Ar of tho
# dy anley aPilecer. Whect aThewheqThlwin,PTweliyW:d werApoal, ayley I
#
# we werey
# ----
# iter 10400, loss: 14.064035
# ----
#   we th the
# rbuhams whe
# d); Pflyondiot ohestontof thataeyehal. Thl. fI vimanns(ous
# pnhan thais wele,kechey of tho of ofes yolestaeceraPclay I whaycerna
# pr; toan aclay Ies ale asbe
# chlak
# rn:ekffW: fiydw
# ----
# iter 10500, loss: 13.450167
# ----
#  he as we al)Ber;:,
# rG(Bechel. (Bef wcamof hounsto
# caucelec. f;e,,
# ifend bygnd tooy shindy;etthauling(B:w: antePtind
# beheqCy(:k
# s n wof As the tof cyeey anhe ass euled inBepracle, In
# rup.mCenhedigfntan
# ----
# iter 10600, loss: 12.834224
# ----
#  nchulolerefiwp vally;er
# mya
# mivanhestynwer:an:ecimy thaustarce afth wot anf
# byhe tonk
# nhecaicBh
# ArWhe);:); vflgcBrTh Glechececteay, nrecaenrvas won of); and acfaecral. Whel
# rurhak fon AerI they wallep
# ----
# iter 10700, loss: 12.215123
# ----
#   we tof tht anst an toalsthe
# prha
# tirIe)
# ArhiyWmank bed ssatthof thaulythbitantsaasn theuly pelemy;
# Whealpanny ton servant
# tce ch awerac ae wee
# tufwmamy ChikPiknk); talty te as, war mqec(e); andathe
# s
# ----
# iter 10800, loss: 11.637102
# ----
#  ha alepecBand bumye
# behelsg(B);kq(Befiy;gn(y; ae any hinh waArecerifhathe I fande aly
# yce cha
# dirh. ok werant
# Polemarn:ecimerne bihale vian was wauf mandsvaeperto offrnaanthecith arsstaube clay I we t
# ----
# iter 10900, loss: 11.554216
# ----
#  rcBeciof I we asy
# on echalipn
# thiwhtaychn
# ecaif bye biande aly
# whisathe
# dinnfon ant
# mannsprval, we ththel. Thally;e); us ak
# rhiPodl. Whel wandovitorernanth as wa terhekdy;emiabhecalaswayeralig
# Areceep
# ----
# iter 11000, loss: 11.202464
# ----
#   we to nrraccluf beceus ton offptole Teralstof Iy th ullprme vhanst(B; we ten thaus
# ai:ecley Cy; n
# ecaecrva thrhek
# bihakd);.W(makkbCmWkpW: Pf:WWBPal,kknWmawk nos d astatthecinW
# us she ynrof I That oul
# ----
# iter 11100, loss: 10.681164
# ----
#  he gofgon me by uf wlebyce); uhalmyerhulkmBenhivfePhiWheustannathe Iof hus Thraly,
# byelm. Thhak
# iranseacen wn aurel. hhecaystanhe asstay, viandesamvanGre)ouf tus ans
# thiaccaat thithrGlaufsthe
# cl.hhigB
# ----
# iter 11200, loss: 10.193149
# ----
#  tclul mye
# bihald Tes
# rfrnand vinteayestivauf whivanesthe, Wheclebihak
# the iorThrald: Whecaycaundecitht ant); Whe sq,
# chaec Glaun thhe, I werat aes rhauf th the tounArvimy
# rf: with Gl..);er
# myal, anley
# ----
# iter 11300, loss: 9.700401
# ----
#   we ion echel
# rnhucith bithe dof toundithay hul. ThesiyTheleby.Gkkbyend watthtayo nre, aple);edes nhe
# ifrul. Whaluld alleprof wastoferecthecercrulle,
# rus won ofnArval, was w I
# prs whacaunervinpre); P
# ----
# iter 11400, loss: 9.209020
# ----
#  hes I wand the Thraldpechecercrhall,peoleranWhe Tht. Whechecadcthas s no yestof das werat aece the Piranno Whecaof yeses I what ok
# inhess,Pinhiyghn:. Pir(man:ecarce
# cl.); Pflamervheley:B); I wenemipra
# ----
# iter 11500, loss: 8.759066
# ----
#  we thhtaycstaicpranrhinontiphaecrecithrvant befe
# bihadestaclepthe
# d, aclay, nhel Iy the ainye
# buhas (Be
# Aecamy an: Pithecaufstirauns woncobeobyhind theak
# ife us ans
# byhaispr
# prol Thr(ld;ePis,gof westa
# ----
# iter 11600, loss: 8.322200
# ----
#   we the
# stauf tf ul. Whe the
# celeak
# Whe as weyemyaechalibehelay Cerhe of CepralleWhecond I wede
# bihak
# pray wraeus anne
# py; hhe Thracpre). Whe thracyoand the Thracnoo Them.);:(B;WGlalknBePionk fn tfral
# ----
# iter 11700, loss: 7.904640
# ----
#  hen I ancinnnemanf
# I was, theuofeCe)halps fprolerAr
# ulll,
# echichin,
# then we vinhnst nonnomcauf the sio)k
# ine
# biWq)Pighighe wn thoun
# prae anf
# th
# ullrvath wen wasterif maecs helwpthakd, I)
# m); WqinBwPik
# ----
# iter 11800, loss: 7.515035
# ----
#  rchul th bhinhebinntofesse
# prold vi: PilgThWyondoI tanwey waak
# whallandivayce, whitastangs. When waineprayers then wa ufrhale TheAsthof myat stinBen whe Pneo was ofer yinghthe
# ssarchon wathe
# celen I o
# ----
# iter 11900, loss: 7.147859
# ----
#   wece cervinansefny inhalutof Arele
# byel
# mWkI wn thaulebit(hemaachingof mneeprvall,Thlomyrgfntinnwpurntt te Themofke); nkecemlyenhit
# rnBe
# Aes my h
# re, I thay starme ThractonestyPolle,kechias,. Iy Iy t
# ----
# iter 12000, loss: 6.828058
# ----
#  he gopamy; nowe
# p); )fenk
# b););rI: WTholimkgh(Bechacle, an: dhe tof mcann I weramyaecroaAsranto braale, whaind,
# tofk
# thecais, the ghr Id an wb hiBe); Whecalnsgy; )hecae, bye bePiBen ine
# bBe
# Tes(e,(B);
# ----
# iter 12100, loss: 6.527633
# ----
#  ncle we
# Atfan rele
# bshak
# bThally; vivantt omnon of Cerold y, Ip vise); Whe Thr(ld eching. I watchuaAprat sarAesaacralBengofdsinnye
# b:enimyanf
# I wede
# behe(my; ws. becl,Wqulus akle ty the chaalep alley
# ----
# iter 12200, loss: 6.544425
# ----
#   wecton fflourvas When wainerele
# behakly;: w wn wargntachanthom of of then of of I weraufont
# marnf
# gchande). I. ak
# brhale, whity onkow the
# dy; hhe Thracekdnhiykwas s
# erelsthe
# my; wst I Pf yston ecayn:
# ----
# iter 12300, loss: 7.245986
# ----
#  he Pirauclay whain, (Benfe iofke); ofers thecaicprak
# re Pis)feus mervinande; Wheus (qulainBephinBerfethey ye thiul. Wheledinnton ndrerinr);e);:W::PGl.:kThimlwb(Bek y wat tos of of ustayced ferifny me
# ----
# iter 12400, loss: 7.128362
# ----
#  uclay wh wathe
# hyhabs andy an:efTheler(B);.); b(kPThist nonncey wbe fht offnna
# the starce I whe I watos.); ofes on we yeref tho fr ho
# d:eandes inaally;eche thaulepecle thaut thas sfathey of I wes mand
# ----
# iter 12500, loss: 6.785203
# ----
#   we ifnrebe
# clay whain, Whecast the m,rayers tonn thho belauclay I,
# tinewvaiwer
# mas
# ifechecaichande The
# srand:eathraly, in andof to of of us wo
# behak
# brof merby andefeminer hiomgrmyThis. Trand non the
# ----
# iter 12600, loss: 6.432892
# ----
#  he Pirolerd); When on hullanns halle, omerbyemk)h
# Gs wowAr:emirb:ecervfen eThecle
# Phif
# nThaus aksh tht of of the ssondracbecannywhandy achiy, thechaclan
# Are
# WBeroldee, yestarnlanindattoolghatienhel th
# ----
# iter 12700, loss: 6.096768
# ----
#  rchus yo
# t fanpestinBen pand bun: un y
# waithral. Wheus. Thal. ThlBer(Brchisgcnoangeof us and beyee theld Ie,
# bihan he
# cloanAtarmy; yWtval, that fisy:echal byeectatley of my uf thithre nBe wle
# chiwfech
# ----
# iter 12800, loss: 5.772830
# ----
#   we thand themepre); Whecold byaund n an an I whiads wh meast.)hrimands; byobd: Thilutntefthe
# kfutas (fechece f
# bis
# d athey thaus
# ginepha(Bengeayey thaes ayeld vle I thh nfe); WhechingoukefemiyTn
# anhe
# ----
# iter 12900, loss: 5.474212
# ----
#  he flepenwestay whaefreayers (Ben:ePiebianAet ta
# pr; fon on weraliuestaeceufechacle
# Thigmank); bCPI wecitheGlant wall,
# rof nTerancle, Ie
# myre
# Aiyou hey an:efit); my
# tfrbs to th
# uin, baAAtathancephallW
# ----
# iter 13000, loss: 5.193717
# ----
#  nchecigchGlup s. Ie the
# ifrecivhnes ace fit(Beng. pocle, I wey an wall, melen:CGkgW(mafd n: berne Pole
# prhal, yrenemye
# biaaulithan theceproclighPhe
# w)Pwe, ynton whe s, the difthe
# sraun:.b(Bek wolerwa(
# ----
# iter 13100, loss: 4.926635
# ----
#   wece nBechuleminef afllnT: Theclebinak
# rsec the
# sprak
# rse ThralyThm(d nton to the
# clagce Thrle,Thr ter to tht alleme); mhanTerbinTkval, Thitertabemayninhrulr, theulof we tha
# AredsiyCens.)Arhlmanksbeu
# ----
# iter 13200, loss: 4.682930
# ----
#  he offThrs
# doens yon Cenhid wo wepraycthaighancophon fquiley on
# he th
# helentechinAr(Bendettance Thrs the); Whe ofrn thel the
# bfh
# mibhe); bBhelotn thaenwaPBe, an: thecaifphallyBeA
# rfBeAtta we heremarf
#
# ----
# iter 13300, loss: 4.453527
# ----
#  rchule
# b:e
# k
# WhePimands afusof thlemarchol wasts; andrecinhak WThels akn: bCwbye bequle
# Thi(gPTh us non the sh bye
# behiussaerauclang.); Pie, yese,prnT
# WseWkdnkwy; Pol,gonionntecatchusthathrwand tanaig
# ----
# iter 13400, loss: 4.235020
# ----
#   wect Poles and bivaulecint;;sWhe: mawk wle thally
# hrs wow)cerain by th wl. Whe asiwertheleye
# be; Theofdkenthaled aclay Iofeuf hold ayle, efled ond tos,grhaled aflep nce fhtalepre (e); Whulst ok ous e
# ----
# iter 13500, loss: 4.034124
# ----
#
# enstyitande
# plauckv):.Pivad inkwneminem alut soak
# fht usreere. Theme, I thathrwarse); Whel. hneoalvanclifqey:ePeece as wous wan sThiul, Ink bBenAs);:Wchel. n: kfqCmwarmlrmaun:. (Bw(wPiCe(k)Thralakkn(
# ----
# iter 13600, loss: 3.848293
# ----
#  tchus the
# sfen anse); Whe as tha
# dintsaufruf tho
# in:); Whewson: bBdmaitherfobye
# bihak
# bralBerhe); Pflylgg(BW
# d: westthe sewast); ffthaens ann); Whe assany
# my ef wh wandsaufle, I e
# sterte Ter. dley of
# ----
# iter 13700, loss: 3.669016
# ----
#   wece fpecaycter mast); fBe, wallmaacleng.ufes wancy teralyeeceecibycey I way hhten afsey ecle
#  go
# duran:e ile
# plaucrvarclun(eechtak
# rs antofestirhe s: belighoec. Whelithoecancerchuak
# rhulemyechityohi
# ----
# iter 13800, loss: 3.506247
# ----
#  hen of of mye
# f:ef afll,
# riBe
# Aef hTh n,
# thandinhibphallWh
# Arhanst on gn thaleprefemathapenfecitarnest); anny ansofe
# bdeallyhea
# dy andetamy yh. annewheme, aAle, In
# mWfedion on on the my byee iofpechal
# ----
# iter 13900, loss: 3.387868
# ----
#  rchus was ansracbound fht on feras any wainc
# rus whingeranteepreclecitand); Whe oleprayers (Beche isrsofemye
# behallmTPfled ond bfens dTerat tolyey; behallWhe); I we te Thracayervaeterthi,
# rsanksrsonde
# ----
# iter 14000, loss: 3.470675
# ----
#   wece clobe
# nheaut festathaus yhaneston on off
# pr: fd andd anleprec ul. Whe Tpratus anhraly, of and vielerben
# marvasteqGlBmyiwnsofrstot ofens youn
# mye
# bihalepThelly; Wsws(Brn: I waets yelecavas and al
# ----
# iter 14100, loss: 3.676413
# ----
#  hel the
# stef
# mcBef whaufrvasto
# pramyaeus wo beGlle); andrectoe stasteroAltan thualmandy the Pihe(dy;e, aye
# b:ec. Whelischuchat andefitho
# cinandy th th; annralis,
# br(BechibThr(Becleptalighhu thraly, hh
# ----
# iter 14200, loss: 3.536189
# ----
#  rclecith vas Wfen we werifntand);.WCmPig. I wh Gitof o
# dun weece claanprvalo financloulhin
# rWhe Thracurnfk
# bihand,
# rvaechocBechal,
# rseak
# ifendibyhns. Thelerv(.kmbGles ak
# bWGPnewsThiGg of on oand
# behri
# ----
# iter 14300, loss: 3.374765
# ----
#   wece fian: Poen wf hik
# Arol. I wels ThelsW(BhWmask f. of ouirhechaclep na
# Arst thracelefref yy. I:ecle, an: thec; chalutot of ngof the
# s, nrecthalephalleWhePionneAthis whal we dus mn
# bs myknThhaewsr:
# ----
# iter 14400, loss: 3.218806
# ----
#  he tof pn
# ucity; Wheclat, nheclabeh us nerauso citchtak
# behally;. wiwakgn Piry: bfdalla(Beching. I (Ben
# ec. htay,
# precBef dfBes an: Pit(
# Pflayqe, vfl. Themiyn:wlinclance a
# bihak
# ArtyPonThthidctants th
# ----
# iter 14500, loss: 3.071884
# ----
#  rchul tho so nhabstanto oce the to Thracur cfanslygh(Bef afle, weley;.Whondofk bGlwn thaustirfechingro
#  uranAeras weye
# bihand,
# rvae sea.
# Whelathoed ht ht eccechalimy;eP tht of the alypeme berayersaiup
# ----
# iter 14600, loss: 2.930628
# ----
#   we toandastingallyhanle,
# chce, I of k
# saecraclay wh thr annewe Teraly echalutWhecighres wbehing)frw; WBI.Gsbuksl. WmeC Inomaut thew nhacle Teraly ef uf wh vinhPisyrby;:kppraleprecaule
# Wfen inheceofer
# ----
# iter 14700, loss: 2.801159
# ----
#  he Thracunnf
# tundsthe
# dr; Wfiy,was wy:yctea. WhalllyhiPBentePfino nne,
# r(Ben ibBend thu of neathe
# chaunrey hbitand the
# srnayfld
# inArw);ndoby byewbitandracy wn tervalmy;. nBelstast); (Be(hi(Bgn(makkrb:
# ----
# iter 14800, loss: 2.684052
# ----
#   chul wasterhall,
# r(Berf: Ck full.tWhalslyofd my bye
# bseak
# ifhallyThnd they wniwy we of terantoes the sonn
# mye
# bitak
# prmaAmy; towey wyewe helemeechmathat oprrbutomergaynrany wasteprval, eclabitechWhem
# ----
# iter 14900, loss: 2.571698
# ----
#   wecton mlann
# by: Po ng. Ievan on onast); fle, I wey the
# sfechechatignhalus chay soon we th; thed we wermyawatta(Ben
# ufemiuncovants aPionnematcluanhrmarcerauflmychand); WBer(lrnkw; wntusttye ofel
# thau
# ----
# iter 15000, loss: 2.464686
# ----
#  hen of of ous co ferusnanprand was anne
# praaifense, I that der(Benfetanig.); Whinde allighseP. WhecomlercBethecaichhallnTock
# Areawpraeclay Cemers watchal, Whechecaactones abyhebiandefityaul. Whallmann
# ----
# iter 15100, loss: 2.364398
# ----
#  rchulightestarce ales anstath
# ulou
#  thithgod helefqulold wbimervantinhecaicercle, I wey talle
# PolemTI); b:kPflygon; wn wn tho I the so n
# rurelyechecightaale, I of usaprrupy yo
# nulnr
# prold on
# gfnninny;
# ----
# iter 15200, loss: 2.269167
# ----
#   wect ok
# ifuld the Thracnngfn:yTAd to of offsta
# t to The
#  fhn usrewin yfans and themhe
# ArhmGBdusoldry of nhr(Bval, by th Glit);ewisbprayershance ano the Porus the
# dye
# biha
# sineWheclenTheks); buwll tot
# ----
# iter 15300, loss: 2.181586
# ----
#  hen of of I we). Ihaakfindralin.); WheTThd winot inand themarpechaandestekdhimyithawnnw ocbe
# mhl. Thrclabinns bquale, allmWheqTuramy we); Whale, beas
# rbalo
# Whe);sbaknd by nnound to beca whthatervay wo
# ----
# iter 15400, loss: 2.100236
# ----
#  rchul. ureclechalus Cephai,mas
# in:yfsd wh testivaechalimy:ecita
# tayly,
# ns annewhelerhalus airauf wl.uf makd waygpraler was anntamy th  chat manns; yhe io, oflmanctawas wlemathemed anlengofps,
# pr:k fta
# ----
# iter 15500, loss: 2.023909
# ----
#   wect now shanceph(B
# nAtPiAwaithouliyerece When the
# s,echaclep vye
# bleayey th as anhay I maan: me whemer;e); WhGllmact bit ou thrald:eclayceusta
# tinesthe, annant, aye urvanly;iwadmyenst of ouir: Ghing
# ----
# iter 15600, loss: 1.952163
# ----
#  hen of of m, wally; bBersl, ghlgho wflyg. Pollsy:daBus weas whtaoffervant
# Pfound the ThralrbesBenCePsiwhrvf PsewThhiwanhe ocas anntaufleprecemasha
# drhay,erer(B
# nArPiggrmyas ofers theu of ma by his cTh
# ----
# iter 15700, loss: 1.886973
# ----
#  rchulold end wainref thaechal.e, whithrelignhalisy;ecith tathathe Polemer(eeclabqele
# bleak
# byead sfrnhiyBerThhuly wealeprvally;ed of tyhalmance on of perthis (Bechat echaclaychon fpraychaans (BeAse);
#
# ----
# iter 15800, loss: 1.823505
# ----
#   wece fitallannye
# bees tand, anle, I that fut o
# nAhall,
# C(Bec; bygrnmaf tce sfechacle Terald of I we thar ffnto berclepref th ulidy;emWe(Benhink
# Pi:,Pirne so femascannsauf the
# cf nhiy, ns and werhe al
# ----
# iter 15900, loss: 1.763049
# ----
#  hiwat saancervanclonyond on of of tullanceecion of)
# gn: mae thralrant
# .); Whe, wayce he
# pfant mally hfse, I
# pe phrwerhat alemianf:.)A:.)kWhecighomeranyemayatArte
# behingfThe weathathelsranus w; anstant
# ----
# iter 16000, loss: 2.780865
# ----
#  rchucervpeak
# Arul. Whecalclancerancle, I we tirauroe shaechinestontaycad ron ofronye
# bihand, in
# wain, an eurep: Whecom thracianye
# bBechichun y,
# hnd thing.); to
#
# that on of thing.); fut the clobyouf nf
# ----
# iter 16100, loss: 3.377493
# ----
#   wece uswathatceecelec. fqule
# bsol;
# Wh. k
# bBe
# Asbamy; andrecines I werecton offson ande The
# tervantWok noun uf my uf th; annew
# buhis pqanchands; bhul. Wneavight of one
# t Ced ondof we ttho nht offsof I
# ----
# iter 16200, loss: 3.359891
# ----
#  he as ant
# by of nc. futok fon offscaunstayhe grr. When marnr
# uyole we he yervant); thed waut foe helerin.); mhinBed wl.myat ok tolaghr
# pun f;eaily;eligand war
# rvanf. noalus an weraifht offnsaelsThrold
# ----
# iter 16300, loss: 3.204510
# ----
#  rchul the
# ston. Whe asranWo
# behally,
# bs Id wat f aclabyhe
# mratim. (e son than sore
# pl. fheaigghaluly un uf we us fea. fhus waehe
# bram fd fusn Iorecthall,,
# n walus on ghraclp no won of Cephal, nhaale,
# ----
# iter 16400, loss: 3.038378
# ----
#   wece nerclaast bhauld thattous chally,
# chkPionThinew(B); P(lWm.):GPigcoI Thrus andatt aussey thaecracleprvallvThe mes aqul. WhePhed we hullmyechinsen)eWheligholes aWlat echacley Iintheaspechalut feli
# ----
# iter 16500, loss: 2.878156
# ----
#  he Thracervines the sBand Pitnrof hh uf the sorp ufl. Thla
# bselk
# b(Bmk ndivattancyauf ty thees I hhithay tot my,pectance wes wall, I of Cerhithecleprefemye
# iBen that so) Iy:kcroak
# prechaluens aufre in
# ----
# iter 16600, loss: 2.726241
# ----
#  nche
# de); Whel tclande, ableWhes mhatoch nhe asservautomwatclulemandsbI); Piggrmy werthis
# rhnthithan marns wa us aclaus ancralig. Thla the Phral,Ththing.vWhiBer(maBknywbyay welamy wh. WheconcePflarner
# ----
# iter 16700, loss: 2.581779
# ----
#   wece nithhecioh my I wecleclonkeAtibphallef thingoulechalus chay sfrus andralifechaclay we dnre, I o
# bshandstaik
# tBeciof anle, werdyewand)(); me:d n: uf now thraldaeclePiofnseityatcl
# b:kPk;brompanc.
# ----
# iter 16800, loss: 2.447868
# ----
#  he Thractanteey aull, Iy
# mandstaeceathite, I that fut o
# rs, birhat mannewalay shastereAThim. Themibnhauk neeneecithobl bye
# bioak
# prefemasta
# by; Whece pon of Cephaikpr. Wfeligh
# eiowr
# his witann:wathiwa
# ----
# iter 16900, loss: 2.323225
# ----
#  rchus we by un mannswinhing. I fus chancephallWThel tn. IpromyghalleyeliBenkebe
# claand); fnta thattof t
# inhecann
# hinespare than,
# nheaignnestableclece ce cemastand beyot of Cephay whrvants ayee ioak
# pr
# ----
# iter 17000, loss: 2.205888
# ----
#   wece fitald Thrals allan th
# me thattonestabe chtaonn
# praly ef
# ti
# hl
# th; antatas hallprelemcrvartervin
# b:BPklwrvantirthausithe
# proly hb:d wlnPnsale, I werse thas mon of Cerhe birpelaunste
# by; thense);
# ----
# iter 17100, loss: 2.098435
# ----
#  he goruliwestay wathat of the sorkenhatien tus manlBenfeferus andoaly,
# nstasterrPT
# nswanst Ceralchulemyerh
# mastant); fhtok. I: Ceece cht aefralee in); une);rWhePimard nkenisustoromyatheche k
# rours, I
# ----
# iter 17200, loss: 1.999424
# ----
#  rchul wasterhallpTol. Whal tandsthik
# prh
# Asrath; Pol. ThiththensePTlakknTme wes
# the
# sithaes echus wasd ban
# din
# re
# town was ifhallyTheliynr); PT: Pisn th GliIye
# bihandraliser tands; the tofksye
# bl,akpr
# ----
# iter 17300, loss: 1.906247
# ----
#   wece n thley anhiye beaulepgofus thrs dinhtesayss nhectoall); (Ben mantirtecleprof mandlanns yhe goremyanf th
# ss has af n
# irhan: fftasternanhrGle, the tore, fofllyhta wherchacancemandseminghiturvant
# ----
# iter 17400, loss: 1.821032
# ----
#  he gorervancob(Benhe igernasterelaufle,
# ef whtay,t took
# Arel.
# WBen mast); Pflygonpobyemlitnhtl dce
# steaApyon of ndracflep of thid, anle, I;
# mankswayBedsoy onTAraldyaufle, If
# tl. wita
# dle the ThracunAs
# ----
# iter 17500, loss: 1.741936
# ----
#  rchus mye
# bialus ama(knTed watt yo fon offnnto
# prefer(Bende as werant
# PolumyenA
# b: PCrwl.Thimatn: bf cf to th
# Pil.);el.mWheqTk Thr t of to the PhaulyThvionprmchalitWhalut felity; antofntofnArvae Terul
# ----
# iter 17600, loss: 1.667142
# ----
#   wece newastafninhr arleprefimyeeclaayeraute bina
# praese me be
# behis
# PT: Pod maathale hele
# blemeechta
# proldancleq of mesbe
# tquhe
# Thawerva(Beng.);ecle; eflond:GPola
# dlluc. Whelasf ththinds CdThesiychal
# ----
# iter 17700, loss: 1.598905
# ----
#  he Thractaund, I to wathat rus werthe
# si(f); IprnpBrnttalepce werer)ye
# (B); Pigromeancale This
# whems wnttht athe
# duntof to
#
# AtalwrTh
# bingwe
# staof sta
# promy;we(: Whel wy th we th; mo wot tos nole,, nhi
# ----
# iter 17800, loss: 1.536939
# ----
#  rchal. Whuligandler Thr. Wfec
# mands; Wfech nnstanclep vallyThe
# gqniw.rvanPiTh weralyaecitandre the  of the
# sprakprol,PerhiyTrus. Thaus noande tha
#
# ifhally;: Ceremerervaechacerulnakprdlat I welemcrhe t
# ----
# iter 17900, loss: 1.478413
# ----
#   wece nercluf wh tholery); wp wl. n
# echalled eclabshall,
# gh. bB;PTed weatigha(Benhianfrvay Ie
# Pon staPo non on ofrndranto wralemapraut mysbin;:Poifnceyemy,
# ifuld thecay, by. Whulathe sfechecightarssan
# ----
# iter 18000, loss: 1.424097
# ----
#  he as were
# cl.;kecleq oflly; bf not ntonds I); Whul.mW(Be
# ks way hn
# mchal,
# Wfen that p thand tht acrann
# myh
# bina
# prom fnttof thralighe
# sraly; bCBmn wh wan ferayers wht anterifnnstandarhrmarce allmarn:
# ----
# iter 18100, loss: 1.373211
# ----
#  rchul wa beref tWhian thas Pflar I werthe
# clea(Ber(:)
# brus ale, I wertofls annBer hr
# dd weliycomatur(lyo
# bshaigrhthoBertu
# dh s shncercruacey efemye
# bialcey;:PiBh mlegne
# prol)
# rus mhinArGlwy)rGlous was
# ----
# iter 18200, loss: 1.325333
# ----
#   wece per alyAece
# behr.my(Ben was weece
# biha
# sriI Thlmaynt noun whaufhtayestighe asinervanted echan helw, tnhinnrGler(B); ck byoyAs attholy was aquast bifgwen waith
# Glaun al. Whes yoles hallepr(Ben: b
# ----
# iter 18300, loss: 1.281962
# ----
#  hen of of Cy. Whelighoe thracingy
# his mon of neralirnnthaleprealebivand); by: Thral, Thiserre
# stye
# himy;ey wall, anlibhendstattofe Thracarnstithenemangofer
# peBen eclaand bifthaus anye
# bihand, of, thea
# ----
# iter 18400, loss: 1.240769
# ----
#  rchelvianstancemarnfwey an:e Thr. In towroly throleThrle, whlggook werth aes
# chley If th tc; annewaycerancleq of th wect nondeminereldamcltW
# Pllan:.Pimaqke, by:my wn th us ef uflepre, I wele
# cl.andif
#
# ----
# iter 18500, loss: 1.201102
# ----
#   wecton mye
# bialceyee)hmande ttas whalut the
# praedsinprvig. beclace n: nBef th
# Pis whof wf hallipenThrimy we) the soon,
# thecithecin
# rhals Whecle, an.inBechiwathe
# starce Tere, the
# tha. ThiI to byhat an
# ----
# iter 18600, loss: 1.165368
# ----
#  hand fithaes was son off
# nf thadd tirta(BenAeptonemyaechalutof and this
# rhe
# Asravy:mWswakky(lyPon:oan: Po ng. I w
# rnhanchallr; Whele
# b:eak
# rhe fsrauthay I of ufrtaycePigche us that of ngotus thathraly
# ----
# iter 18700, loss: 1.132202
# ----
#  rchulas avrslyI byenTeraly,wbGlalutaunnArvae werant
# Iy th ulitankswaycedstingdno ctanee Cebiabusishandy;s nt
# bs a
# dl
# rlyensenfrwhiy,
# bsaldinhtally; bpealmyoul. woel ty us aflarchomerphallmTanAer wlaut
# ----
# iter 18800, loss: 1.100132
# ----
#   wechal,prsestibePhleyqThluw toukstewyethot fhracyanTh ak
# Ares of wh marnf thelmWhally; Wfir(l,
# CnT
# vi
# byochown hallbphalmWhemimard Thecigcfece bet of ntathibyWh. Th at ous the
# tsaathe); WhePighthe by
# ----
# iter 18900, loss: 1.070942
# ----
#  he Piraufe, iaand TksbinBems wbeth tands
# ay: PneaThralyPeslenc.); W(Bef waetservaechal. Whel. pne); anrr. Whinhey whattous usrehin.); Whingonrenclauknnwasd ourrphrlephalleyeefetihus wathe mervast); to
# ----
# iter 19000, loss: 1.044037
# ----
#  rchus wle; The
# .y; wpev(lab anle, I we the
# pranchel th thercr.); Whe as (erslypraBestayh
# nown hrald Cechol. n:rme, Be the mernawurthat of the asrann
# e
# dalus chay s, thes wa turnayers the as an o
# bshak
# ----
# iter 19100, loss: 1.017639
# ----
#   wece ns (BenAebiayceranclocanc
# Pflem ecloant); ff wrrgctalknk
# b:hal, nd yo fhacle iay thalinhl
# pralcpem: PflykkPT
# d me on on chralrfe); tflus nk:wce noun wns nhtatton thal. Whucleprefervivant); theds
# ----
# iter 19200, loss: 0.992775
# ----
#  he gofgof me bh th ta
# ulold of merefthalererviep mas andractoe Arseaifensidhew wanttaaylswanth iskmWok ThrPitaut the
# hines anhof werst ot furth torus we thes yhtaBehtayounon fe the
# drpr the
#  yhtbitand
# ----
# iter 19300, loss: 0.968909
# ----
#  rchul the
# sinht
# es ant); Wfele
# bBendibhI); byon on of nde
# trGlWfknsok Ceaity by the ston I fef th ul.. Thius ntond ouy werauclay ef theGlBenhebiha
#
# y: PieWhiPAsy manttomeaut thathe
# pragcle); Wsoungwai
# ----
# iter 19400, loss: 0.946379
# ----
#   wece frtalla
# rle
# ble); Whed mantt oflemanns; bhal. Whechale, he, wf war go
#  themsenhWhebyanThral, Thise); fhidTers bB:kprd: watt olersi
# prs wo fecton ofrndyatiful. Whelighoe teralp vle I thlwy thathe
# ----
# iter 19500, loss: 0.926757
# ----
#  hen of of the son ef neramyewbithhthayeleprebimycedion on on ob on of ndr. wle); Whed tantt of us weraligereciancle, oflonne); nfland))wWB; Thva tf t of Cerhe s.); Whaalleg.iB
# Ar
# bygndoIntiron of Cerh
# ----
# iter 19600, loss: 0.906823
# ----
#  rchul the
# sterthiaan: Whealop alley ef uf themerd, I); nht CerWI);:yayers wato vanctancou mervayte, whawy wh wesaun
# mannseriBgholy hdBeranthe gookeroe shancprafle, Cnhing. T
# eciyThhlwaniwbehanst to ce
# ----
# iter 19700, loss: 0.888716
# ----
#   wect af rhe asayers yhe gofCephalutusta;hat ok futus annewhe
# pranthhand westiree feratirurwly,
# ifurshin the ofr
# pr. Whe thracinnye
# Phe of thralig.); mTly;wI we alyeechtak
# roces ande
# prme the thn of a
# ----
# iter 19800, loss: 1.156511
# ----
#  hen maigof notf the
# stanold an hus f; anstan thr mernasterhally;:(k:(Bmad Whiygonprmy b(; The
#  un wn I te any uf the
# sprvief th uloI fetemarclo
# chulimye
# bee itands; butally; (he aste
# behiok Ilg onnomy
# ----
# iter 19900, loss: 1.662799
# ----
#  rchul yest thay stithe sorngrof thracyone
# byhw thand fon men wh we wermyandst nor men wh was won that sinn
# by th wathat of the asrechauf uf the
# bihamyght); Tk
# b: IWt noun thauss (Bendetarcluf wh his s
# ----
# iter 20000, loss: 1.652531
# ----
#   wecton mce
# biIGok nertivainhe, wist); ff nsedctaPilThrGlef bu: cthale); bsaaAsy I); Whe of Cerhe anawertisain: and ththey eflodk
# Whivigh weye
# (:ef
# hireprobesyaun: b:BPallangowervin
# prauf the
# spechman
# ----
# iter 20100, loss: 1.590828
# ----
#  he gorkchouion thraly,
# Wheles nhr(l,Pinhed whawayo non ofp
# Iy th tarhand waicereclaund in nfece
# prvaisd whimacha derelirvast byankndwblmund fon shanclaay we man: nce teran ofeAsatheA
# yhe ind we wervan
# ----
# iter 20200, loss: 1.520279
# ----
#  rchus we the
# spechinhe as that fis. wh th Th we arle
# rs and weraufn yeecehlebingh(inArviof th thralifechalitWhalibye
# clay we vclonAr); bpoalmy; wn th tad lBenhibuI werans wy un mands; yhecimann; ay: W
# ----
# iter 20300, loss: 1.449221
# ----
#   weclabitants; PfrPith meranWhus Iy uflmanns. Whe ssrerron asrer); Whe of Cerhe annthandralllephalus weW. bBef tht afto warhe
# bingcCmprmerta(BeAriBeeus aneray tertirauclay wh wannsway thaechaluly:ecer
# ----
# iter 20400, loss: 1.382678
# ----
#  he so k
# rold aBeld Ie
# ran wThe de birof onn
# Arst thrwathe(Bemhabimandf. whecawbehallWThhitartsast Ie, I westableneeclabeef uf thrus wnranprvigd ban: wo non of wermarceratustatarcI I wheusestare to
# ree
# ----
# iter 20500, loss: 1.319649
# ----
#  nchul wasts; bBerimervn: bs; Th wlechrulecancley anleyeeplePithe starhe sof mands; Whelaufe bitant); Wf:Pid (Beclerern
# echacle, aflmaath mealep thauy eclay wl. PienThink);qI wertayce Thesty; wsthaksd
# ----
# iter 20600, loss: 1.260023
# ----
#   wecton mangs; then of the
# sprak
# bihPksy;maPilgufn
# dst (lecht offervae Teralinef I westighe weray wervaechamerectolasAr(araecraclay ef th
# Glauchalus ;erthtauclay Ied o westardfw
# byele
# bsalk
# rstastingh
# ----
# iter 20700, loss: 1.205466
# ----
#  he so); Whecavas arnally aclat afleprefemye
# bihlolinI W
# dimyawey the sinasta
# prat terth as weramyaechalus. uflly; WhinBenst); Wcemk bPoelifnthan fina
# proldarus werofun that fer athe as s WhecoI the
# si
# ----
# iter 20800, loss: 1.154546
# ----
#  rchus wa beleqBe TrralyBe(Bef mhl
# Tq.akkbyoPaly, WfewsgWhed of wentebeq(Ben of wan sfechan I w
# cluannthaispron on that sas werway, noanderan seathe sh by uf wlet ; untaycance Pflay on
# vrlanTed of of o
# ----
# iter 20900, loss: 1.106896
# ----
#   wece nttaals the cht offArto the Thraciany my of athay hel. Thallygof mancephe)iIy;e the wer W(Back bemathe
# sranthibnhallangok. Cerighalerwe)esr:vanTnGwalut(ouf the
# stechus I we of Cerhe the
# t holiby
# ----
# iter 21000, loss: 1.063590
# ----
#  he asranf
# Iy westand way hht Pfld eus tonn
# min
# sBatoon ans chtally,
# nleraciowbighPindmPawalue an weralinghthitirule
# pran thr
# praldprvBensebTh(kdfTk kon teratcs checton of toles,ris nhe as, we wervantw
# ----
# iter 21100, loss: 1.022959
# ----
#  nchel tht behis sfrvleay to now thraly,
# AmemhI wofrdt of thralinhr
# ithr(g.WhiPimaster tasbervallyTholly)obrond bygho watha I we offnwaut my phrmarnh. In; by I wentof wh tirhr
# pralcBer(mal, (Becidnoun
# ----
# iter 21200, loss: 0.984762
# ----
#   wect nold I wedamy whaey I we of tore, beclepr flebionksto
# bihand, thity ofksthingsand); Whecith Gl. fhtaalinhe
# sranWhelighte the thf nof Cefht toauces annye
# behimyragdigq(Bekstas wralemabh
#
# my; WqTh
# ----
# iter 21300, loss: 0.950205
# ----
#  he ifrus werau terectome thhlstathe if,
# arlayned inhight(Ben of thlem abemy;e); annyghin ffat manctany Iy tht aftomy wlemdfnth
# md tigon owishelerhe ant
# Pileprec. fhulity;ebePilundetatyhus wands; When
# ----
# iter 21400, loss: 0.917772
# ----
#  inhecighthed of the thracinnfet ntaftin stian fhalus ann
# by; be, if,
# Ar.lWfec
# rbuGditththis whalee aechingerauflan wf
# mink
# big. b: Pilung.)heleechta
# prold atht torur uprecton of Cepht tele
# bBhn lGf th
# ----
# iter 21500, loss: 0.887268
# ----
#   we toaThracto beecithe
# siI Thiterwe ttas yon offstardswathed of the
# byhakBnThhat Pisyewithaulithtomyinhaweyewbihaksranyeeuso)k
# hrwarchachn Inewath; my tos weol. Wheathat of the sord to nreferceecity;
# ----
# iter 21600, loss: 0.859790
# ----
#  he asrant
# Pilance); WhinfsbidcTuslethohl thitheGluby,
# ifecity theightalsranc
# dllurstyolek
# httatirhaclebialk
# bfe
# prvae warhe any
# I This Iqually; wk byoulstant);ele
# inhauld wan y, thighneserAehis anntof
# ----
# iter 21700, loss: 0.833913
# ----
#  rbees austs; bhelemye
# bithimy th wek
# westnreak
# Wfelighheliyantf; inal
# wi: Pk:)PiGkmaw
#  fonnemye
# Cem(akm: tf:kcirnoey we wlnhalwral, whimyants; I eleman.); WhinBereesishe
# b hlowervfntirhaPis,
# themifI
# b
# ----
# iter 21800, loss: 0.809451
# ----
#   wece nBecith Glaufleb alou ofeAtrht wernly of on fArthrGly;. wo wlec. non of utanpracye beufemyechiwh winn, atomerd: tonethe clep the
# buhathrp anstanf th
# t f
# stirhe asranfus kere the Porllra. Thelsy;
# ----
# iter 21900, loss: 0.787396
# ----
#  he Thracin.);gk The thnGlauce beeaity;echubemyanf ul. Wheciof nfe
# binaw
# rhtPis, weyettou ofusta
# pral, whithrGlaunrvanhek: The manctyan
# bramar spank
# bBen we ml. WhinprPity tertatuinstastereaine
# prolyg
# ----
# iter 22000, loss: 0.766477
# ----
#  rchulold and thivaund to non of Cephai,
# rse
# k
# byeAAsG(mI weramy uflmants; y
# wn wan fhate tBe(eePish;eye
# bshad finast); Pflathe PolemyIyWmand bitoo stef thrus tht aftathe
# proldanche Thracbrand tow aufA
# ----
# iter 22100, loss: 0.746760
# ----
#   wect nold I we ain
# rurulitn:tmisdctobinnwinht of the
# trvandd Thr tiraece ce
# cl.ak
# rs movy tald ofen thin, anhe ast thaed aclan wast); Whed thatof th th; annewhimgofurvinne); (Bef ibyon onnomandasty;
# ----
# iter 22200, loss: 0.729135
# ----
#  he Thracinnt(B Thr(urnlwathe
# tr.iWhin: bBwecle Teray sdatteley ife
# cl. Thikdf CectondwancBep of the
# prancs nhen:.(B:)kkprmay wo waste
# byhecsewWhbuwal, asta
# ks; Whelighoe tiraund sonfethe
# sprandrsay,
# b
# ----
# iter 22300, loss: 0.712307
# ----
#  ncle  hallipr(Benhe asye
# beelite
# dl.myaCl, bBendoby wn thhtayceshinds;inheciof bye
# blaacs aecemast,;er.m(BephalBecr noe tof th PalleG:qulisGwAlay to
# t the
# prand wl. Whenown I we aly wciay wha nhayeeus
# ----
# iter 22400, loss: 0.696216
# ----
#   wece clncleurul. Whealeprefemye
# Whe isrsbyBeArtandsaais (Bechat ma nerdh
# chtayers (Ben
# eferis and wayhe choaldpechifhta
# tof tous thauss (Ben march Polly anhithtally,
# Whes of the soon we th; wl.Whigk
# ----
# iter 22500, loss: 0.681669
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-3039c2d1ddbc> in <module>()
#      19
#      20     #forward seq_length characters through the net and fetch gradient
# ---> 21     loss, dWxh, dWhh, dWhy, dbh, dby, hprev=lossFun(inputs, targets, hprev)
#      22     smooth_loss=smooth_loss*0.999+loss*0.001
#      23     if n%100 ==0:
#
# <ipython-input-35-065cdb9c1a30> in lossFun(inputs, targets, hprev)
#      11         xs[t]=np.zeros((vocab_size,1))  #encode in 1-of-k representation
#      12         xs[t][inputs[t]]=1
# ---> 13         hs[t]=np.tanh(np.dot(Wxh, xs[t])+np.dot(Whh, hs[t-1]+bh)) #hidden state
#      14         ys[t]=np.dot(Why, hs[t])+by #unnormalized log probabilities for next chars
#      15         ps[t]=np.exp(ys[t])/np.sum(np.exp(ys[t])) #probabilities for next chars
#
# KeyboardInterrupt:
